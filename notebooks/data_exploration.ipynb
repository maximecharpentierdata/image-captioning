# %% [markdown]
# # Trying to explore and use the COCO dataset

# %%
import sys
sys.path.append("../")

import os
from pycocotools.coco import COCO
from src.config import DATA_ROOT_PATH

# %%
train_set = COCO(os.path.join(DATA_ROOT_PATH, "COCO", "train", "captions.json"))
# Out:
# loading annotations into memory...
# Done (t=1.41s)
# creating index...
# index created!

# %%
imgToAnns = train_set.imgToAnns
train_set.imgs
# Out:
# {57870: {'license': 5,
#   'file_name': 'COCO_train2014_000000057870.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000057870.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 16:28:13',
#   'flickr_url': 'http://farm4.staticflickr.com/3153/2970773875_164f0c0b83_z.jpg',
#   'id': 57870},
#  384029: {'license': 5,
#   'file_name': 'COCO_train2014_000000384029.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000384029.jpg',
#   'height': 429,
#   'width': 640,
#   'date_captured': '2013-11-14 16:29:45',
#   'flickr_url': 'http://farm3.staticflickr.com/2422/3577229611_3a3235458a_z.jpg',
#   'id': 384029},
#  222016: {'license': 1,
#   'file_name': 'COCO_train2014_000000222016.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000222016.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 16:37:59',
# ...

# %%
test_set = COCO(os.path.join(DATA_ROOT_PATH, "COCO", "test", "captions.json"))
# Out:
# loading annotations into memory...
# Done (t=0.11s)
# creating index...
# index created!

# %%
test_set.imgs
# Out:
# {523573: {'license': 2,
#   'file_name': 'COCO_test2014_000000523573.jpg',
#   'coco_url': 'http://images.cocodataset.org/test2014/COCO_test2014_000000523573.jpg',
#   'height': 500,
#   'width': 423,
#   'date_captured': '2013-11-14 12:21:59',
#   'id': 523573},
#  347527: {'license': 2,
#   'file_name': 'COCO_test2014_000000347527.jpg',
#   'coco_url': 'http://images.cocodataset.org/test2014/COCO_test2014_000000347527.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 15:12:02',
#   'id': 347527},
#  413171: {'license': 3,
#   'file_name': 'COCO_test2014_000000413171.jpg',
#   'coco_url': 'http://images.cocodataset.org/test2014/COCO_test2014_000000413171.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-14 16:40:04',
#   'id': 413171},
#  102283: {'license': 3,
#   'file_name': 'COCO_test2014_000000102283.jpg',
#   'coco_url': 'http://images.cocodataset.org/test2014/COCO_test2014_000000102283.jpg',
#   'height': 640,
# ...
